# %%
import pandas as pd

# %%
df=pd.read_csv("laptop_sales.csv")
print("Data set loded")
# Out:
# Data set loded

# %%
#to no find rows and columns
df.shape
# Out:
# (1020, 29)

# %%
# to get info such as type of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1020 non-null   int64
#  1   Name                    1020 non-null   object
#  2   Brand                   1020 non-null   object
#  3   Price                   1020 non-null   int64
#  4   Rating                  1020 non-null   float64
#  5   Processor_brand         1020 non-null   object
#  6   Processor_name          1020 non-null   object
#  7   Processor_variant       996 non-null    object
#  8   Processor_gen           891 non-null    float64
#  9   Core_per_processor      1008 non-null   float64
#  10  Total_processor         573 non-null    float64
#  11  Execution_units         573 non-null    float64
#  12  Low_Power_Cores         1020 non-null   float64
#  13  Energy_Efficient_Units  1020 non-null   int64
# ...

# %%
# display 5 rows
df.head(5)
# Out:
#    Unnamed: 0                                               Name    Brand  \
# 0           0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP
# 1           1  Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo
# 2           2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...       HP
# 3           3  Samsung Galaxy Book2 Pro 13 Laptop (12th Gen C...  Samsung
# 4           4  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno
#
#    Price  Rating Processor_brand Processor_name Processor_variant  \
# 0  50399    4.30             AMD    AMD Ryzen 5             5600H
# 1  26690    4.45             AMD    AMD Ryzen 3             7320U
# 2  37012    4.65           Intel  Intel Core i3             1215U
# 3  69990    4.75           Intel  Intel Core i5             1240P
# 4  23990    4.25           Intel  Intel Core i3            1115G4
#
#    Processor_gen  Core_per_processor  ...           Graphics_name  \
# ...

# %%
# let's remove the unnamed column
df = df.drop("Unnamed: 0",axis=1)

# %%
df.columns
# Out:
# Index(['Name', 'Brand', 'Price', 'Rating', 'Processor_brand', 'Processor_name',
#        'Processor_variant', 'Processor_gen', 'Core_per_processor',
#        'Total_processor', 'Execution_units', 'Low_Power_Cores',
#        'Energy_Efficient_Units', 'Threads', 'RAM_GB', 'RAM_type',
#        'Storage_capacity_GB', 'Storage_type', 'Graphics_name',
#        'Graphics_brand', 'Graphics_GB', 'Graphics_integreted',
#        'Display_size_inches', 'Horizontal_pixel', 'Vertical_pixel', 'ppi',
#        'Touch_screen', 'Operating_system'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Length: 1020, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Name                        0
# Brand                       0
# Price                       0
# Rating                      0
# Processor_brand             0
# Processor_name              0
# Processor_variant          24
# Processor_gen             129
# Core_per_processor         12
# Total_processor           447
# Execution_units           447
# Low_Power_Cores             0
# Energy_Efficient_Units      0
# Threads                    48
# RAM_GB                      0
# RAM_type                   22
# Storage_capacity_GB         0
# Storage_type                0
# Graphics_name               2
# Graphics_brand              2
# Graphics_GB               652
# Graphics_integreted         2
# Display_size_inches         0
# Horizontal_pixel            0
# Vertical_pixel              0
# ppi                         0
# Touch_screen                0
# Operating_system            0
# dtype: int64

# %%
df['Processor_variant'].isnull().sum()
# Out:
# np.int64(24)

# %%
df[df['Graphics_GB'].isnull()][['Graphics_name','Graphics_integreted']].head(30)
# Out:
#                    Graphics_name Graphics_integreted
# 1            AMD Radeon Graphics               False
# 2             Intel UHD Graphics               False
# 3         Intel Iris Xe Graphics               False
# 4             Intel UHD Graphics               False
# 5           Intel Integrated UHD                True
# 7             Intel UHD Graphics               False
# 8       Intel Integrated Iris Xe                True
# 9                  Intel Iris Xe               False
# 10                Intel Graphics               False
# 11           AMD Radeon Graphics               False
# 13  Apple M1 Integrated Graphics                True
# 14              Intel Integrated                True
# 17              Apple 8 Core GPU               False
# 18    AMD Radeon Radeon Graphics               False
# 20                AMD Radeon AMD               False
# 22             AMD Radeon Vega 7               False
# 23                    8-Core GPU               False
# ...

# %%
df[df['Graphics_GB'].notnull()][['Graphics_name','Graphics_integreted']].head(30)
# Out:
#                  Graphics_name Graphics_integreted
# 0          AMD Radeon RX 6500M               False
# 6      NVIDIA GeForce RTX 4060               False
# 12     NVIDIA GeForce RTX 3050               False
# 15  NVIDIA GeForce RTX 3050 Ti               False
# 16     NVIDIA GeForce RTX 2050               False
# 19     NVIDIA GeForce RTX 2050               False
# 21     NVIDIA GeForce RTX 4050               False
# 26     NVIDIA GeForce RTX 4050               False
# 29     NVIDIA GeForce RTX 4050               False
# 30     NVIDIA GeForce GTX 1650               False
# 31     NVIDIA GeForce RTX 2050               False
# 32     NVIDIA GeForce RTX 3050               False
# 33    ‎NVIDIA GeForce RTX 3050               False
# 34     NVIDIA GeForce RTX 4060               False
# 38     NVIDIA GeForce RTX 4060               False
# 39    ‎NVIDIA GeForce RTX 3050               False
# 40     NVIDIA GeForce RTX 3050               False
# ...

# %%
df[
    (df['Graphics_GB'].notnull()) &
    (df['Graphics_integreted'] == True)
][['Graphics_name','Graphics_GB','Graphics_integreted']]
# Out:
#                   Graphics_name  Graphics_GB Graphics_integreted
# 326  Intel Integrated ARC A530M          4.0                True

# %%
df[
    (df['Graphics_GB'].notnull()) &
    (df['Graphics_integreted'] == True)
][['Graphics_name','Graphics_GB','Graphics_integreted']]
# Out:
#                   Graphics_name  Graphics_GB Graphics_integreted
# 326  Intel Integrated ARC A530M          4.0                True

# %%
df['Brand'].nunique()
# Out:
# 31

# %%
df.nunique()
# Out:
# Name                      1020
# Brand                       31
# Price                      561
# Rating                      17
# Processor_brand              7
# Processor_name              36
# Processor_variant          125
# Processor_gen               13
# Core_per_processor          12
# Total_processor              8
# Execution_units              5
# Low_Power_Cores              2
# Energy_Efficient_Units       2
# Threads                     14
# RAM_GB                      10
# RAM_type                    12
# Storage_capacity_GB         10
# Storage_type                 4
# Graphics_name              136
# Graphics_brand               7
# Graphics_GB                  6
# Graphics_integreted          2
# Display_size_inches         22
# Horizontal_pixel            22
# Vertical_pixel              22
# ppi                         62
# Touch_screen                 2
# Operating_system            13
# dtype: int64

# %%
df[df['Graphics_name'].isnull()]
# Out:
#                                                   Name   Brand  Price  Rating  \
# 648  Huawei Qingyun L540 Laptop (Kirin 9006C/ 16GB/...  Huawei  81999     4.3
# 998  Dell Vostro 5630 Laptop (13th Gen Core i7/ 16G...    Dell  94990     4.6
#
#     Processor_brand                Processor_name Processor_variant  \
# 648       HiSilicon  HiSilicon  Kirin 9006C 9006C             9006C
# 998           Intel                 Intel Core i7             1355U
#
#      Processor_gen  Core_per_processor  Total_processor  ...  Graphics_name  \
# 648            NaN                 NaN              NaN  ...            NaN
# 998           13.0                10.0              2.0  ...            NaN
#
#      Graphics_brand  Graphics_GB  Graphics_integreted  Display_size_inches  \
# 648             NaN          NaN                  NaN                 14.0
# 998             NaN          NaN                  NaN                 16.0
#
# ...

# %% [markdown]
# Graphics-related attributes were missing for two records. Since the remaining laptop specifications were available and the missing values affected only a small portion of the dataset (2 out of 1020 rows), the records were retained to avoid unnecessary data loss.

# %%
df[df['Total_processor'].isnull()]
# Out:
#                                                    Name    Brand  Price  \
# 0     HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...       HP  50399
# 1     Lenovo V15 G4 ‎82YU00W7IN Laptop (AMD Ryzen 3 ...   Lenovo  26690
# 4     Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...    Tecno  23990
# 10    Wings Nuvobook V1 Laptop (11th Gen Core i5/ 8G...    Wings  24990
# 11    Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...   Lenovo  26739
# ...                                                 ...      ...    ...
# 1004  HP Victus 16-d0302TX Gaming Laptop (11th Gen C...       HP  55999
# 1008  HP 14s-dr3003TU 832T7PA Laptop (Pentium Silver...       HP  26800
# 1012  Infinix INBook X2 Slim Series XL23 Laptop (11t...  Infinix  34990
# 1017  HP Victus 15-fb0131AX Gaming Laptop (AMD Ryzen...       HP  58800
# 1018  Asus Vivobook 16 2023 M1605YA-MB521WS Laptop (...     Asus  54999
#
#       Rating Processor_brand        Processor_name Processor_variant  \
# ...
